# %% [markdown]
# <a href="https://colab.research.google.com/github/wavaronr/InteligenciaArtificial-/blob/main/prototipo_diagnostico_medico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
    Creado el 12 de abril de 2023

    Creado por: Briyid Dayana Coy Coy - Código: 1007788684
                Wilmer Alexander Varón Rodríguez - Código: 1013601371

    90169: Inteligencia Artificial
    Grupo: 51
          
    Descripción: Este programa es un prototipo de un diagnóstico médico
    que se basa en la información que el usuario ingrese y la base de conocimiento proporcionada.
'''
''' 
    Importamos librerias necesarias para el funcionamiento del programa y la predicción
    de la enfermedad del usuario en base a los sintomas que el ingrese, adicionalmente asignamos el método a una variable para su posterior uso.
'''
# Importamos la libreria para el arbol de decisión llamada tree, el sklearn nos permite usar el arbol de decisión, esto nos permite entrenar el modelo y predecir la enfermedad del usuario en base a los sintomas que ingrese.
from sklearn import tree # Libreria para el arbol de decisiones.
arbol_decision = tree.DecisionTreeClassifier() # Variable para el arbol de decisiones.
import os
""" 
    Creamos las listas que nos van a permitir generar la base de conocimiento, entrenar el modelo y que serán insumo para las posteriores búsquedas lineales que usaremos para la predicción de la enfermedad.

    * sintomas: sintomas que se evaluarán
    * enfermedades: enfermedades posibles que se predecirán en base a los sintomas ingresados por el usuario.
    * tratamiento: será el arrojado usuario en base a la enfermedad que se prediga.
"""
# Base de conocimiento.

# Lista de sintomas, los cuales serán los insumos para la predicción de la enfermedad, se tomaron en cuenta los sintomas generales de las enfermedades digestivas, y los particulares asociadas a la lista de enfermedades.
sintomas = ['Sangrado', 'Distensión', 'Estreñimiento', 'Diarrea', 'Acidez gástrica', 'Incontinencia', 'Náuseas', 'Vómitos', 'Dolor en el abdomen', 'Problemas para tragar', 'Aumento o pérdida de peso', 'Fiebre', 'Color amarillo en la piel y en la parte blanca de los ojos (ictericia)', 'Dolor en la parte superior derecha o media del abdomen durante al menos 30 minutos', 'Heces con sangre', 'Falta de apetito', 'Dolor abdominal que se irradia hacia la espalda.', 'Sensibilidad al tocar el abdomen.','Pulso acelerado.','Cansancio','Sangrado rectal', 'Orina oscura', 'Heces de color arcilla']

#Lista de enfermedades a predecir, de acuerdo con los sintomas que ingrese el paciente y el entrenamiento desarrollado en el programa.
enfermedades = ['Colecistitis', 'Cálculos Biliares', 'Proctitis', 'Hepatitis B', 'Gastroenteritis', 'Intoxicación alimentaria', 'Pancreatitis', 'Pólipos en el colon']

# Tratamiento para cada enfermedad.

tratamiento = ['Colecistitis', 'Cálculos Biliares', 'Proctitis', 'Hepatitis B', 'Gastroenteritis', 
                'Intoxicación alimentaria', 'Pancreatitis', 'Pólipos en el colon']

#Tratamiento para la enferemead de Colecistitis               
tratamiento[0] = "- Antibióticos que debe tomar en casa para combatir la infección\n- Dieta baja en grasa (si puede comer)\n- Analgésicos"

# Tratamiento para la enfermedad de cálculos biliares
tratamiento[1] = "- Algunos examenes para confirmar el diagnóstico son:\n- Ecografía abdominal, Tomografía computarizada abdominal, Ultrasonido endoscópico\n- No requiere cirugía\n- La técnica que se utiliza más comúnmente se denomina colecistectomía laparoscópica\n- Dieta baja en grasas\n- Medicamentos para disolver los cálculos biliares\n- Extracción quirúrgica de la vesícula biliar en casos severos"

# Tratamiento para la proctitis
tratamiento[2] = "- Antibióticos para tratar la infección\n- Medicamentos antiinflamatorios\n- Dieta rica en fibra\n- Higiene adecuada de la zona afectada\n- Se usan antibióticos si una infección está causando el problema\n- Los corticosteroides o los supositorios o enemas de mesalamina pueden aliviar los síntomas de algunas personas"

# Tratamiento para la hepatitis B
tratamiento[3] = "- Reposo en cama\n- Consumir alimentos saludables\n- Evitar el consumo de alcohol\n- Medicamentos antivirales en casos crónicos\n- Si tiene hepatitis B aguda, es probable que no necesite tratamiento\n- Algunas personas con hepatitis B crónica no necesitan tratamiento. Pero si tiene una infección crónica y los análisis de sangre muestran que la hepatitis B podría estar dañando su hígado, es posible que deba tomar medicamentos antivirales"

# Tratamiento para la gastroenteritis
tratamiento[4] = "- Reposo en cama\n- Consumir líquidos claros y evitar alimentos sólidos\n- Medicamentos para aliviar los síntomas"

# Tratamiento para la intoxicación alimentaria
tratamiento[5] = "- Reposo en cama\n- Consumir alimentos ligeros, evitar grasas y especias\n- Hidratarse con agua o bebidas de suero\n- Analgésicos para el malestar"

# Tratamiento para la pancreatitis
tratamiento[6] = "- Hospitalización en casos graves\n- Ayuno para descansar el páncreas\n- Hidratación intravenosa\n- Analgésicos para el dolor\n- Dieta baja en grasas después de la recuperación"

# Tratamiento para los pólipos en el colon
tratamiento[7] = "- Extirpación quirúrgica de los pólipos\n- Seguimiento regular para detectar nuevos pólipos\n- Dieta rica en fibra\n- Medicamentos para prevenir la formación de pólipos"

# Función para mostrar la información de los desarrolladores, se muestra al inicio del programa.
def desarrolladores(): 
    print("")
    print("Software para diagnóstico médico")	
    print("Desarrollado por:\n Briyid Dayana Coy Coy - Código: 1007788684\n Wilmer Alexander Varón Rodríguez - Código: 1013601371")
    print("Recuerde que esto es con fines informativos, y el diagnostico difiere por múltiples factores, consulte su médico de confianza.")
    print("")

# Método para entrenamiento, en el cual se van a tomar tres sintomas y cuatro sintomas para la predicción
'''
    @arbol_decision: Variable arbol de decisión. 
    @SintomasPaciente: Lista de sintomas que ingresa el usuario.
'''
def pred_3_sintomas(arbol_decision, SintomasPaciente): # Función para entrenamiento, esta tomará tres sintomas para la predicción de la enfermedad, la variable arbol_decision permite el entrenamiento del modelo bajo el algoritmo de arbol de decisión, y la variable SintomasPaciente es la lista de sintomas que ingresa el usuario y permite la predicción de la enfermedad.
    # Lista de sintomas que se van a tomar para la predicción.
    x = [[6, 7, 12], [7, 6, 12], [12, 6, 7], [12, 7, 6], [6, 12, 7], [7, 12, 6], [13, 11, 6], [11, 6, 13], [6, 13, 11], [6, 11, 13], [11, 13, 6], [13, 6, 11], # Colecistitis
         [6, 7, 8], [7, 8, 6], [8, 6, 7], [8, 7, 6], [7, 6, 8], [6, 8, 7], [6, 11, 12], [11, 12, 6], [12, 6, 11], [12, 11, 6], [11, 6, 12], [6, 12, 11], # Cálculos Biliares
         [2, 14, 20], [14, 20, 2], [20, 2, 14], [20, 14, 2], [14, 2, 20], [2, 20, 14], # Proctitis
         [3, 19, 21], [19, 21, 3], [21, 3, 19], [21, 19, 3], [19, 3, 21], [3, 21, 19], [11, 19, 22], [19, 22, 11], [22, 11, 19], [22, 19, 11], [19, 11, 22], [11, 22, 19], [8, 12, 15], [12, 15, 8], [15, 8, 12], [15, 12, 8], [8, 15, 12], [12, 8, 15], # Hepatitis B
         [8, 13, 7], [8, 7, 13], [13, 8, 7], [13, 7, 8], [7, 8, 13], [7, 13, 8], # Gastroenteritis
         [3, 6, 7], [3, 7, 6], [6, 3, 7], [6, 7, 3], [7, 3, 6], [7, 6, 3], [16, 11, 3], [16, 3, 11], [11, 16, 3], [11, 3, 16], [3, 16, 11], [3, 11, 16], [3, 11, 7], [3, 7, 11], [11, 3, 7], [11, 7, 3], [7, 3, 11], [7, 11, 3], # Intoxicaxion alimentaria
         [8, 16, 17], [8, 17, 16], [16, 8, 17], [16, 17, 8], [17, 8, 16], [17, 16, 8], [6, 7, 17], [6, 17, 7], [7, 6, 17], [7, 17, 6], [17, 6, 7], [17, 7, 6], # Pancreatitis
         [0, 14, 19], [0, 19, 14], [14, 0, 19], [14, 19, 0], [19, 0, 14], [19, 14, 0]] #Pólipos en el colon
             
    # Lista de enfermedades que se van a tomar para la predicción.
    y =["Colecistitis", "Colecistitis", "Colecistitis", "Colecistitis","Colecistitis", "Colecistitis", "Colecistitis","Colecistitis", "Colecistitis", "Colecistitis", "Colecistitis", "Colecistitis", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Cálculos Biliares", "Proctitis", "Proctitis", "Proctitis", "Proctitis", "Proctitis", "Proctitis", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Hepatitis B", "Gastroenteritis","Gastroenteritis", "Gastroenteritis", "Gastroenteritis", "Gastroenteritis", "Gastroenteritis", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria", "Intoxicación alimentaria","Intoxicación alimentaria", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis" ,"Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pancreatitis", "Pólipos en el colon", "Pólipos en el colon", "Pólipos en el colon", "Pólipos en el colon", "Pólipos en el colon", "Pólipos en el colon"]

    # Entrenamiento del modelo. 
    # La variable arbol_decision recibe el entrenamiento del modelo, el cual se basa en los sintomas y las enfermedades osea el valor de (x,y)
    arbol_decision = arbol_decision.fit(x,y)
    # Predicción de la enfermedad.
    # La variable prediccion_enfermedad recibe la predicción de la enfermedad, la cual se basa en los sintomas que ingrese el usuario.
    prediccion_enfermedad = arbol_decision.predict([SintomasPaciente])
    # Retornamos la predicción.
    return prediccion_enfermedad

# Función que permite leer los sintomas ingresados por el paciente, y además de eso muestra un listado númerado para facilitar el ingreso de los sintomas.
def leerSintomas(): # Funcion para leer los sintomas
  ListSintom = [] # Lista para almacenar los sintomas
  # Se muestran los sintomas que se pueden seleccionar para el diagnostico medico.
  print("Cuales sintomas presentas maximo 3: ")
  # Se recorre la lista de sintomas para mostrarlos al usuario, se le suma 1 a la variable i para que el usuario pueda seleccionar el sintoma que desee.
  for i in range (len(sintomas)):
    print(i+1,sintomas[i],"\n")
  # Se recorre la lista de sintomas para que el usuario pueda seleccionar los sintomas que desee, se le resta 1 a la variable valor para que el sintoma seleccionado se almacene en la lista ListSintom.
  for j in range (3):
    valor_valido = False # Variable para validar el valor ingresado por el usuario.
    while valor_valido == False: # Mientras el valor ingresado por el usuario sea diferente a un número entero, se mostrará un mensaje de error.
        try: # Código a ejecutar para cualquier excepción, en este caso se valida que el valor ingresado por el usuario sea un número entero, de lo contrario se mostrará un mensaje de error.
            valor = int(input(f"Ingrese el número del sintoma ({j + 1}): "))
            ListSintom.append(valor-1)
            print("Usted ingreso el sintoma:",sintomas[valor-1])
            print("")
            valor_valido = True
        except Exception as e:
            #elimina la ultima posicion que no esta en el listado
            ListSintom.pop()
            # Código a ejecutar para cualquier otra excepción
            print("\nEl valor ingresado está errado, por favor ingrese nuevamente el número del sintoma que presenta\n")
            valor_valido = False
    
  return ListSintom

salida = False # Variable para controlar el ciclo while que permite reiniciar el programa para un nuevo diagnostico médico o salir del programa.

while salida == False:
    desarrolladores() # Se llama la función para mostrar la información de los desarrolladores.
        # Función para mostrar la información de las enfermedades y obtener los sintomas que el usuario presenta.
    SintomasPaciente = leerSintomas()
    diagnostico =  pred_3_sintomas(arbol_decision, SintomasPaciente)
    print("El diagnóstico médico es:", diagnostico[0],"\n")
    # Se busca la enfermedad en la lista de enfermedades para mostrar el tratamiento.
    index_enfermedad = enfermedades.index(diagnostico[0])
    print("El tratamiento es:")
    print(tratamiento[index_enfermedad])
    print("\n¿Desea realizar otro diagnóstico?")
    print("1. Si")
    print("2. No")
    opcion = input("Ingrese la opción: ")
    if opcion == "1":
        salida = False
        # Limpiar la información en consola
        os.system("cls")
    else:
        salida = True
        print("Gracias por usar nuestro software de diagnóstico médico :)")
# Out:
# Software para diagnóstico médico
# Desarrollado por:
#  Briyid Dayana Coy Coy - Código: 1007788684
#  Wilmer Alexander Varón Rodríguez - Código: 1013601371
# Recuerde que esto es con fines informativos, y el diagnostico difiere por múltiples factores, consulte su médico de confianza.
#
# Cuales sintomas presentas maximo 3:
# 1 Sangrado
#
# 2 Distensión
#
# 3 Estreñimiento
#
# 4 Diarrea
#
# 5 Acidez gástrica
#
# 6 Incontinencia
#
# 7 Náuseas
#
# 8 Vómitos
#
# 9 Dolor en el abdomen
#
# 10 Problemas para tragar
#
# 11 Aumento o pérdida de peso
#
# 12 Fiebre
#
# 13 Color amarillo en la piel y en la parte blanca de los ojos (ictericia)
#
# 14 Dolor en la parte superior derecha o media del abdomen durante al menos 30 minutos
#
# 15 Heces con sangre
#
# 16 Falta de apetito
#
# 17 Dolor abdominal que se irradia hacia la espalda.
#
# 18 Sensibilidad al tocar el abdomen.
#
# 19 Pulso acelerado.
#
# 20 Cansancio
#
# 21 Sangrado rectal
#
# 22 Orina oscura
#
# 23 Heces de color arcilla
#
# ...
